# %% [markdown]
# # 更加可靠的检索
#
# 更加可靠的检索方法，增加了检查文档相关性和防止幻觉，以确保检索信息的准确性和相关性。

# %%
import re
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["MINIMAX_GROUP_ID"] = os.getenv("MINIMAX_GROUP_ID")
os.environ["MINIMAX_API_KEY"] = os.getenv("MINIMAX_API_KEY")

from langchain_qdrant import QdrantVectorStore
from langchain_community.chat_models import MiniMaxChat
from langchain_community.embeddings import MiniMaxEmbeddings
from langchain_community.document_loaders import TextLoader
from langchain_core.documents import Document
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_core.output_parsers import StrOutputParser

# %% [markdown]
# ### 第一步 文档加载和分块
# 加载基于txt的文档并将其拆分为更小的、可管理的块，以促进高效的向量编码和检索。

# %%
file_path = ('../data/问答题.txt')
loader = TextLoader(file_path, encoding="utf-8")
documents = loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/问答题.txt'}, page_content='挂失解挂\n挂失解挂，快速响应，保证号卡安全\n一键解挂，轻松恢复\n服务链接：https://wapah.189.cn/fjcfw/zzgsjg.wap\n\n\n资费专区\n套餐资费一目了然，选择更轻松\n资费专区，各类套餐资费信息抢先看\t\n服务链接：https://wapact.189.cn:9001/provincialarea/provincialarea.html?provCode=600301\n\n\n补换卡\t线上换卡，足不出户\t号卡用不了？不用急，专属补换卡服务帮您迅速搞定！\t\n服务链接：https://ah.189.cn/cms/r/cms/ah/default/v2020/replaceCard/index.html\n\n\n已定业务\t\n服务链接：https://wapah.189.cn/busQueryAuth/newBusPackageInit.wap\n\n\n充值话费\t\n服务链接：http://wapah.189.cn/index/rechargeIndex.wap?fromSource=QYWX\n\n\n订购流量\t\n服务链接：http://wapah.189.cn/handle/packageIndex.shtml?fromSource=QYWX\n\n\n积分兑换\t\n服务链接：http://wapah.189.cn/exchange/exchangeInit.shtml?fromSource=QYWX\n\n\n套餐余量\n服务链接：http://wapah.189.cn/used/newUsedAmountQry.wap?m=-1&fromSource=QYWX\n\n\n服务进度查询\t\n服务链接：http://ah.189.cn/cms/r/cms/ah/default/v2018/repairSheet/querySheet.html?B9wgfv37VqnX=1714291687044\n\n\n宽带远程停复机\n服务链接：http://wapah.189.cn/ua/toLogin.shtml\n\n\n已办业务查询\t\n服务链接：http://wapah.189.cn/busQueryAuth/newBusPackageInit.wap?fromSource=QYWX\n\n\n详单查询\n服务链接：http://wapah.189.cn/detail/detailQueryInit.shtml?m=-1&fromSource=QYWX\n\n\n电子发票\n服务链接：https://ah.189.cn/cms/r/cms/ah/default/v2016/electronicInvoice/wap/login.html\n\n\n服务提醒\t\n服务链接：http://wapah.189.cn/remind/remindQuery.shtml?fromSource=QYWX\n\n\n宽带问题\n服务链接：https://it.anhuitelecom.com:8292/AHBbService/welcomeLogin.do?token=\n\n\n账单查询\t\n服务链接：http://wapah.189.cn/bill/easyBillInit.wap?m=-1&fromSource=QYWX\n\n提问：宽带坏了，无线网，wifi，ITV机顶盒电视用不了\n回答：您好，宽带障碍莫着急，您看一下光猫和路由器上指示灯在亮吗？如果指示灯不亮或者灯亮无法上网，您可以把光猫路由器等设备电源断电，等2分钟后把线路重新连接一下再重启试试\n\n\n提问：无线网，手机上网，手机看视屏很慢\n回答：很抱歉影响您使用了，网络慢，手机卡顿和好几种情况都有关的~比如路由器的摆放位置、承重强影响信息覆盖、家里面积大小、路由器设备老化，线路问题等等。\n\n\n提问：光猫，路由器有灯亮，不能用\n回答：亲，线路正常时光猫上的光信号灯是常亮状态，如果不正常，先进行网线排查，检查连接网线是否老化松动，把设备端口的网络重新插拨后重启即可。如果不行的话需要维护人员上门处理\n\n\n提问：我要办理宽带移机，迁宽带\n回答：宽带需要换个地址对吧~ 您可以带身份证到附近营业厅进行办理，也可以拨打10000号选择线上办理，都是可以的哦\n\n\n提问：存费活动\n回答：预存300/600元话费，爱奇艺，优酷，腾讯视频会员任一，还有水电劵，加油款，购物劵随选，话费分月返(300分6个月，600元分12个月)\n\n\n提问：流量不够用怎么买流量\n回答：来啦~现在有流量包在做活动，每个月送20G流量+热门APP会员权益，您号码多少我来查询能否办理呢\n\n\n\n\n提问：老用户有什么福利活动吗\n回答：有的呀亲，可以扫码领取500M流量，名额有限，先到先得呀\n\n\n提问：电信用户生日有什么福利活动吗\n回答：有的呀亲，安徽电信准备了生日专属福利，限量送美团外卖10元红包券！限量10000份，先到先得！我给您发送一个链接，您点进去看一下是否能领取。\n\n\n问：我家宽带猫坏了怎么办？\n答：如果您的设备是自己购买的，需要自行寻找维修点处理哦！如果您是租用我们的设备，您可以通过以下方式与我们的客服人员联系： 1、关注“安徽电信”微信公众号，进入在线客服； 2、您可以登录http://t.cn/RvbDlQV 下载安装安徽电信掌上10000客户端，在首页下方的快捷入口点击“更多服务”→“修障服务”→“在线客服”。 具体以工作人员联系告知为准。\n\n\n问：光猫丢了怎么办？\n答：如您的光猫是自购的，需要您自行购买； 如您的光猫是租用电信公司的，需要前往电信营业厅按原价进行购买，具体以营业厅工作人员告知为准。\n\n\n答：宽带提速需要换猫吗？\n问：您办理提速后，后台会自动检测您的光猫进行判断，确保您的光猫和您的宽带速率相适配，保证您能享受到办理的宽带速率。\n\n\n问：我在电信网点购买的机顶盒的保修期多久？\n答：电信机顶盒的主机保修一年，在保修期内如果不是人为损坏，是可以享受免费服务的，具体可以查看机顶盒的使用说明及三包凭证。\n\n\n问：宽带光猫有哪几种？\n答：目前安徽电信现网使用的光猫终端主要为普通光猫和天翼网关，天翼网关相较普通光猫，主要增加了无线功能和端口数量。\n\n\n问：电视机遥控器跟机顶盒遥控器功能怎么合并？\n答：感谢您的关注！通过遥控器学习功能，机顶盒遥控器可以学习电视机遥控器开关机、音量调节功能，在观看iTV时可以通过学习后的功能键对电视机进行开关机和电视机音量调节操作。 iTV遥控器学习键使用方法： 1、按住“学习”键约3秒，红色灯长亮； 2、10秒内按下“电视机电源”键，红灯闪烁； 3、将原电视机遥控器与本机两头相距3CM正对，按电视机电源键约3秒，红灯闪烁三下后长亮，学习成功； 4、重复2、3步骤，学习其它按键，按一下设置退出学习状态。\n\n\n问：为什么我看直播节目正常，点播的有一些影视节目，界面提示机顶盒版本过低，需要更换怎么办？\n答：您好，您家里的机顶盒因性能比较低，无法支持下载安装观看节目所需的客户端，可前往当地电信营业厅咨询更换机顶盒，具体以实际受理为准。\n\n\n问：我的安卓手机网速太慢了\n答：先生/女士，您反映的手机上网慢问题，我们为您核查了平台数据，4G显示开通状态，也没有限速记录/上月限速本月1号凌晨已恢复，现给您发送一条短信，您按照短信内容操作测试一下，如果未恢复，建议您按照短信的第三步去营业厅，让工作人员帮助您换机或换卡测试，可以吗？请问您使用苹果手机还是安卓手机？\n您好，经核实您的上网数据正常，本月无达量降速记录，初步判断为您的手机或UIM卡问题。\n请您按照以下步骤操作测试：\n第一步：请重新启动手机移动数据开关。\n第二步：释放缓存并重启手机。\n第三步：请将手机卡取出放在其他电信手机上测试。如网速仍未恢复，初步判断手机UIM卡故障，建议您携带有效证件至到营业厅换卡处理。温馨提示：更多问题请关注安徽电信微信公众号ahdxwt，点击“在线服务”选择“修障服务”可自助排除宽带、iTV、手机、固话障碍。祝您生活愉快！"\n\n\n问：我的苹果手机网速太慢了\n答：先生/女士，您反映的手机上网慢问题，我们为您核查了平台数据，4G显示开通状态，也没有限速记录/上月限速本月1号凌晨已恢复，现给您发送一条短信，您按照短信内容操作测试一下，如果未恢复，建议您按照短信的第三步去营业厅，让工作人员帮助您换机或换卡测试，可以吗？请问您使用苹果手机还是安卓手机？\n苹果手机\n您好，经核实您的上网数据正常，达量降速已于本月1号恢复，\n请您按照以下步骤检查您的手机终端或UIM卡：\n第一步：请重新启动手机移动数据开关操作。\n第二步：点击设置/通用/还原/还原网络设置（请勿点击其他还原选项，会造成您手机存储数据丢失），输入开机密码，手机会自动重启。\n第三步：请将手机卡取出放在其他电信手机上测试。如网速仍未恢复，初步判断手机UIM卡故障，建议您到营业厅，让工作人员帮助您处理。温馨提示：更多问题请关注安徽电信微信公众号ahdxwt，点击“在线服务”选择“修障服务”可自助排除宽带、iTV、手机、固话障碍。祝您生活愉快！"\n\n\n问：我家已有电信/移动/联通宽带还能再移一条宽带吗?\n答：您好，具体资源情况需要师傅上门检测 ...

# %% [markdown]
# 使用正则表达式根据特定分隔符分割文本

# %%
separator = "\n\n"
chunks = re.split(separator, documents[0].page_content)
# 去除空块
chunks = [chunk.strip() for chunk in chunks if chunk.strip()]
# list转换为Document格式
docs = []
for chunk in chunks:
    docs.append(
        Document(
            page_content=chunk,
            metadata={"source": documents[0].metadata["source"]}
        )
    )
docs
# Out:
# [Document(metadata={'source': '../data/问答题.txt'}, page_content='挂失解挂\n挂失解挂，快速响应，保证号卡安全\n一键解挂，轻松恢复\n服务链接：https://wapah.189.cn/fjcfw/zzgsjg.wap'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='资费专区\n套餐资费一目了然，选择更轻松\n资费专区，各类套餐资费信息抢先看\t\n服务链接：https://wapact.189.cn:9001/provincialarea/provincialarea.html?provCode=600301'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='补换卡\t线上换卡，足不出户\t号卡用不了？不用急，专属补换卡服务帮您迅速搞定！\t\n服务链接：https://ah.189.cn/cms/r/cms/ah/default/v2020/replaceCard/index.html'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content
),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：我的苹果手机网速太慢了\n答：先生/女士，您反映的手机上网慢问题，我们为您核查了平台数据，4G显示开通状态，也没有限速记录/上月限速本月1号凌晨已恢复，现给您发送一条短信，您按照短信内容操作测试一下，如果未恢复，建议您按照短信的第三步去营业厅，让工作人员帮助您换机或换卡测试，可以吗？请问您使用苹果手机还是安卓手机？\n苹果手机\n您好，经核实您的上网数据正常，达量降速已于本月1号恢复，\n请您按照以下步骤检查您的手机终端或UIM卡：\n第一步：请重新启动手机移动数据开关操作。\n第二步：点击设置/通用/还原/还原网络设置（请勿点击其他还原选项，会造成您手机存储数据丢失），输入开机密码，手机会自动重启。\n第三步：请将手机卡取出放在其他电信手机上测试。如网速仍未恢复，初步判断手机UIM卡故障，建议您到营业厅，让工作人员帮助您处理。温馨提示：更多问题请关注安徽电信微信公众号ahdxwt，点击“在线服务”选择“修障服务”可自助排除宽带、iTV、手机、固话障碍。祝您生活愉快！"'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：我家已有电信/移动/联通宽带还能再移一条宽带吗?\n答：您好，具体资源情况需要师傅上门检测，若您所在的区域具备安装资源，就可以。若无安装资源，则不可以。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：我想办理跨地市办理移机？\n答：抱歉，目前不支持跨省跨地市办理移机。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：你们最近是有个存费送权益的活动吗\n答：您好，感谢您对安徽电信的关注，目前是有预存300元/600元，协议期6/12个月，分6/12个月返还话费，每个月返50元话费，并赠送对应的大权益包活动。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：存费送权益活动期多久\n答：您好，2024-08-01 00:00:00 开始到 2024-12-31 23:59:59 结束，如果您需要请及时参加。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：存费送权益我能参加吗\n答：您好，目前这个活动针对安徽电信翼支付预付费、后付费手机用户均可办理'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：存费送权益的活动内容是什么样的\n答：活动1：预存300元，协议期6个月，分6个月返还话费，每个月返50元话费，并赠送大权益包A包。\n活动2：预存600元，协议期12个月，分12个月返还话费，每个月返50元话费，并赠送大权益包B包。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：存费送权益的的权益包是什么\n答：大权益包A包：以下权益每月N选2：爱奇艺周卡/优酷周卡/腾讯周卡/5元水电煤缴费券/5元中石油加油券/5元商户券\n大权益包B包：以下权益每月N选1：爱奇艺月卡/优酷月卡/腾讯月卡/15元水电煤缴费券（5元*3张）/15元中石油元券/15元商户券（5元*3张）\n大权益包在总价值不减少的前提下，包含的内容可能会不定期进行更新调整，具体见翼支付客户端权益专区展示内容。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：存费送权益的话费怎么返还和使用呢\n答：当月起逐月返还话费，首月返还话费办理后24小时内到账，后续每月1日返还话费。返还话费可抵扣月基本费等通信费用，不能抵扣国际及港澳台费用、漫游国际港澳台费用，不能抵扣电信代收的信息服务费。\n话费查询路径：掌上10000 APP-更多服务-业务办理-充值交费-右上角交费记录;\n分月返还查询路径：掌上10000 APP-分月返还计划-预存300元分6个月返话费享大权益包A/预存600元分12个月返话费享大权益包B。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：存费送权益中的权益怎么领取呢\n答：权益领取规则：协议期内用户每个自然月可领取当月权益；用户需开通翼支付账户，且订购权益包的号码与翼支付账户为同一号码，用户领取权益的账户为订购权益包的手机号。\n需登录翼支付APP领取权益。当月权益仅限当月领取，过期不可补领，如有欠费需缴清欠费。同一终端（手机）每月限制登录3个翼支付账号领取权益包内容，如达上限会触发风控风险提示，可更换终端设备登录领取。\n权益领取路径为:\n活动1：翼支付APP-底部“权益”入口-我的权益包-预存300元享大权益包A_6个月-点击立即领取按钮;\n活动2：翼支付APP-底部“权益”入口-我的权益包-预存600元享大权益包B_12个月-点击立即领取按钮。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：最近有办理流量包活动吗\n答：来啦~现在有流量包在做活动，每个月送20G流量+热门APP会员权益，您号码多少我来查询能否办理呢'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：流量橙翼会员包是什么呢\n答：您好，主卡首次订购流量橙翼会员包30元/月（包含20GB流量包和翼支付白金会员权益），签订12个月协议，可享受分月返120元翼支付代金券（10元/月*12个月）和100元翼支付代金券（一次性到账）。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：流量橙翼会员包协议多久\n答：订购流量橙翼会员包均有12个月协议期。 2、协议期内如用户因过户、离网、退订、携号转网等原因需提前解约请至电信自有营业厅、掌上10000客户端进行退订，按约定进行违约赔偿，违约金计算方式： （1）翼支付权益：按照10元/月*已履约月份数； （2）100元代翼支付代金券：（代金券金额/协议期）*未履约月份数。 其中，协议取消当月计入已履约月份，违约金四舍五入取整。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：流量橙翼会员包到期后怎么办\n答：1.协议到期后，30元20GB流量包和翼支付白金会员权益（12个月）默认按月自动续约，如您不需要此业务，可自主退订30元20GB流量包和翼支付白金会员权益（12个月）。\n2.协议到期后，如您未主动退订30元20GB流量包和翼支付白金会员权益（12个月），默认按30元/月收费，可继续享受包内流量和翼支付权益。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：全光组网怎么办的？\n答：网速慢不要急，现在有FTTR全光组网，光纤通到每个房间实现全屋千光wifi覆盖，让您的房间信号能够更快更稳定！'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：全光组网现在费用怎么样\n答：2024年7月1日-2024年9月30日活动期间，您通过本活动页面下单办理全光组网（FTTR）业务，月资费30元/月（含1个主网关20元/月+1个边缘网关10元/月），设备为集采月付免费租用，每季度享1次免费上门网络调优服务。业务竣工后，可获得50元翼支付权益金＋1个月会员权益。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：全光组网安装后赠送的50元翼支付权益金怎么领取\n答：您好，50元翼支付权益金业务竣工后的10个工作日内充值至您主卡号码翼支付账户中，您到时可以通过翼支付充值使用。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：现在办理业务为什么还要签名啊\n答：您好，现在根据实名制要求业务办理需要完成签名，您可以通过您正常在用的手机关注“安徽电信”微信公众号，点击对话框回复“激活”，点击宽带/其他业务，点击准备好了，请在方框处正确输入下单时填写的身份证号码、校验码，（校验码，将短信通知到您下单登记联系电话里）点击提交校验，根据页面提示身份认证，即可完成视频认证。认证成功并有短信通知，之后等待电信工作人员处理订单。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：积分怎么兑换\n答：您好，您可以通过网厅、短信厅、掌上10000、“安徽电信”微信公众号可以参与积分兑换活动：1、积分兑换流量包；2、积分兑换话费直充卡；3、积分兑换短信包'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：积分在哪兑换呢\n答：参与方式一：您可以登录网上营业厅（网址：http://ah.189.cn/service/point/exchange_init.action）积分兑换。\n参与方式二：编辑指定短信发送到指定代码。\n参与方式三：登录掌上10000客户端-积分-更多兑换，积分兑换。\n参与方式四：您可关注安徽电信微信公众号并通过手机号码绑定或点击https://wx.ah.189.cn/wxws/zbimg/xcxsbhd.html\u2002-我的福利-选择积分兑换。\n参与方式五：请添加我们官方微信公众号“安徽电信”，点击在线服务-服务大厅兑换积分，或点击在线客服与我们即时沟通！期待您的联系！'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问
'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：我们怎么查询到积分呢？\n答：您好，您可以通过以下四种方式查询：\n1、网厅积分查询，请点击：http://ah.189.cn/service/point/point_service.action ；\n2、登录掌上10000客户端积分查询（客户端下载请点击：http://t.cn/RvbDYPp ）或登录掌厅http://wapah.189.cn 查询；\n3、短信方式：本机编辑短信105或JFCX发送到10001能查询；\n4、本机拨打10001，按“1”进入可根据语音播报选项选择查询。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：为什么我查询不到积分？\n答：您好，目前电信积分是星级客户的一项权益，非星级客户不享受积分回馈。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：电信积分是怎么计算的？\n答：您好，电信积分是根据您的实际消费计算的，每消费一元积一分。再以您的消费积分为基数，乘以星级对应的积分倍数。不同星级回馈不同的积分倍数。1星是1倍，2星是1.5倍，3星是2倍，4星是2倍，5星是3倍，6星是4倍，7星是5倍。例：某6星客户本月消费实缴费用为500元，本月获得积分为500*4=2000分。\n（温馨提醒：如参与购机送费、存费送费、年付等活动所赠送的费用，不属于实际消费，不参与积分计算）'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：电信的积分有使用期限吗？\n答：您好，积分有效期以自然年为计算单位，三年为一个有效期，实行滚动清零，每年12月底执行。即您在第一年获得的积分，只要在第三年年底之前使用都有效。\n也即2016年产生的积分将在2018年12月31日清零，在清零前我们会通过网厅、营业厅、积分商城、短信等多种方式发布积分到期清零公告。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：我因欠费被停机了，积分还能使用吗？\n答：您好，抱歉，您必须缴清欠费后才能继续使用您的积分。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：我能把积分转给朋友吗？\n答：您好，目前暂不支持积分转赠功能。您可将积分兑换成物品后再赠送给您的朋友。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：我进行套餐变更后，原有的积分还保留么？\n答：您好，变更套餐有可能会导致原积分失效，建议您在变更套餐前兑换。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：我怎么去兑换我的积分呢？\n答：您好，您可以通过以下方式兑换：\n1、网厅积分兑换，请点击：http://ah.189.cn/service/point/exchange_init.action；\n2、掌上10000客户端兑换积分（客户端下载请点击：www.ahzs10000.com/a.html ）或登录掌厅http://wapah.189.cn兑换积分；\n3、短信方式：手机编辑短信9发送到10001进行操作；\n4、积分商城兑换：请点击：http://jf.189.cn（已支持单宽用户）'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：人工可以给我兑换积分么？\n答：您好，目前积分暂不支持人工在线兑换，如需兑换可登陆全国积分商城兑换，网址为：http://jf.189.cn。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：电信积分可以做什么？\n答：您好，您获得的回馈积分可用于兑换或消费电信提供的产品，而且还可以通过网厅、积分商城、掌上10000、短信等方式使用积分兑换礼品。\n电信还会不定期举办各类积分俱乐部活动，您可根据您的兴趣爱好使用积分参与俱乐部活动。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：在哪可以查询到附近电信营业厅？\n答：您好，您微信关注“安徽电信”公众号，左下角打开对话框，搜索“营业厅”后点击链接即可查询到您附近营业厅地址、电话、工作时间以及服务范围，还可一键导航。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：手机上的附近营业厅功能能干什么？\n答：您好，附近营业厅功能是依托智能手机终端，根据用户所在地寻找附近营业厅的功能，同时提供营业厅地址、服务时间、服务范围，可地图导航。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：营业厅信息给的不准确怎么办？\n答：您好，您可以通过微信公众号中的在线客服，向我们提出不准确的内容，我们将及时改进。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：怎么查询其他区域、城市的营业厅？\n答：您好，您关注安徽电信微信公众号并通过手机号码绑定或点击https://wx.ah.189.cn/wxws/zbimg/xcxsbhd.html ，左下角打开对话框，搜索“营业厅”默认定位的是您当前所在区域的营业厅，如果查询其他区域或城市的营业厅可按下面方式操作：\n1、手动拖动“地图搜索区”至您所需要的区域或城市；\n2、在搜索框输入“营业厅”即可定位您附近的营业厅。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：怎么查询手机的PUK码？\n答：您好，您可以通过如下路径进行查询：\n①网上营业厅：您访问安徽电信网上营业厅：ah.189.cn，右上角选择{消费者帮助中心}-{常用查询-PUK码查询}，登录后，即可查询。\n②掌上10000客户端：您可本机登陆安徽掌上10000客户端-我的-在线客服-输入“PUK码查询”-根据弹出的信息“点击这里”，即可查询。\n③短信方式：手机正常状态下，您可编辑免费短信604发送至10001，查询PUK码信息。\n④手机正常状态下，您可本机拨打10001查询PUK码信息。 路径：进入智能语音导航后，普通话直接说“PUK码查询”，根据语音提示的方法操作即可。\n⑤您可联系视频客服查询PUK码（非实名、未登记个人证件信息的政企单位用户不提供查询）。\n⑥您登录中国电信APP-查询办理-手机-全部-服务-便民-我的PUK码--进入机主信息确认页面默认登录号码/输入号码，姓名，身份证号码，点击查询-活体认证人脸信息采集授权页-我的PUK码信息页即可查看PUK码。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：为什么PUK码正确，但是不能解锁？\n答：您好，PUK码可输入10次，若都输入错误，UIM卡会被彻底锁定。需携带机主有效证件至电信营业厅办理补换卡手续，更换新的UIM卡。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：所有手机都有PUK码吗？\n答：您好，所有电信手机UIM卡都有PUK码。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：补换卡后手机卡的PUK码会变吗？\n答：您好，换卡后PUK码会变，每张手机卡都有一个单独的PUK码。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：办理宽带包年的价格是多少？\n答：您好，不同兆数的宽带年付费用不一样，具体如下：\n50M宽带包年720元、包两年1200元，100M宽带包年960元、包两年1600元，200M宽带包年1200元,300M宽带包年1500元,500M宽带包年2200元,1000M宽带包年5900元。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：单宽年付用户的年付期从次月1日起生效，当月如何收费？\n答：您好，（一）新入网用户办理当月按过渡期资费收取，即年付价格/365天*竣工日到当月底的剩余天数（包两年用户每天收费为“两年付价格/730天”）。例如，12月10日宽带竣工，办理960元包年，首月收取960/365*22=57.86元。\n（二）年付到期用户到期后再办理续约，办理当月按上一年年付价格折算收取，即上一年年付价格/365天*当月剩余天数折算收取费用（上一期为两年付用户按730天折算）。\n（三）单宽月付用户办理年付，办理当月仍按原月付价格收取。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：办理宽带年付起始时间从什么时候开始计算？\n答：您好，年付周期从次月起计算。如3月10日入网办理包1年套餐，年付时间为4月1日至次年3月31日。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：办理了宽带年付与手机合账缴费，是否会因为手机欠费停机导致宽带停机？\n答：您好，单宽年付与账户下手机不同停同复。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：什么是单宽带？\n答：您好，单宽带就是只开通宽带一种业务。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：单宽带和融合宽带有什么区别？\n答：您好，单宽带是指只开通宽带一种业务；融合套餐是指含有固话、手机、宽带、iTV等多种产品组合的套餐。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：年费宽带到期欠费没有注销会产生费用吗？\n答：您好，宽带年付用户到期后如未及时续约，宽带到期后自动停机，有预存款也不能使用，停机后不再产生费用。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：我装了你们电信的宽带，可以使用以前我自己购买的光猫吗？\n答：您好，如您是在安徽电信营业厅购买的光猫，并且您家现在宽带接入方式和以前一样的话，可以使用以前的光猫设备。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：手机上怎么查看家里的宽带是多少M网速？\n答：您好，您可以通过以下方式查看您家的宽带速率：\n1、关注“安徽电信”微信公众号，进入在线客服→修障服务→宽带排障；\n2、您可以登录  http://www.ahzs10000.com/a.html  下载安装安徽电信掌上10000客户端，在首页下方的快捷入口点击“更多服务”→“修障服务”→宽带排障。'),
#  Document(metadata={'source': '../data/问答题.txt'}, page_content='问：怎么查询家里宽带上网方式？\n答：您好，如您每次上网都需要点击“宽带连接”说明您是拨号上网，如您开机就可以直接上网说明您是通过路由器上网。')]

# %% [markdown]
# ### 第二步 创建向量存储
# 利用Qdrant和MiniMaxEmbeddings嵌入将文档块向量存储中，从而实现高效的基于相似性的检索。

# %%
embeddings = MiniMaxEmbeddings()
vectorstore = QdrantVectorStore.from_documents(
    docs,
    embeddings,
    url="http://localhost:6333/",
    prefer_grpc=True,
    collection_name="007"
)

# %% [markdown]
# ### 第三步 问题查询
# 使用检索器来查询问题，并从向量存储中检索相关文档块。

# %%
# 创建检索器，相似度；返回文档块数量
retriever = vectorstore.as_retriever(
                search_type="similarity",
                search_kwargs={'k': 5},
            )

question = "存费送权益的活动有哪些？"
context = retriever.invoke(question)
context
# Out:
# [Document(metadata={'source': '../data/问答题.txt', '_id': '0c45d39c-1f3f-4c9f-9cec-5ce82ef9b306', '_collection_name': '007'}, page_content='问：存费送权益活动期多久\n答：您好，2024-08-01 00:00:00 开始到 2024-12-31 23:59:59 结束，如果您需要请及时参加。'),
#  Document(metadata={'source': '../data/问答题.txt', '_id': '53c0d279-ec97-456e-a577-6866518ac391', '_collection_name': '007'}, page_content='问：存费送权益的活动内容是什么样的\n答：活动1：预存300元，协议期6个月，分6个月返还话费，每个月返50元话费，并赠送大权益包A包。\n活动2：预存600元，协议期12个月，分12个月返还话费，每个月返50元话费，并赠送大权益包B包。'),
#  Document(metadata={'source': '../data/问答题.txt', '_id': 'f9a7ee88-3680-4b80-a74b-a9bed4bc40c0', '_collection_name': '007'}, page_content='问：存费送权益我能参加吗\n答：您好，目前这个活动针对安徽电信翼支付预付费、后付费手机用户均可办理'),
#  Document(metadata={'source': '../data/问答题.txt', '_id': '5658881a-a4be-49ea-91c4-bcc136815caa', '_collection_name': '007'}, page_content='问：存费送权益的的权益包是什么\n答：大权益包A包：以下权益每月N选2：爱奇艺周卡/优酷周卡/腾讯周卡/5元水电煤缴费券/5元中石油加油券/5元商户券\n大权益包B包：以下权益每月N选1：爱奇艺月卡/优酷月卡/腾讯月卡/15元水电煤缴费券（5元*3张）/15元中石油元券/15元商户券（5元*3张）\n大权益包在总价值不减少的前提下，包含的内容可能会不定期进行更新调整，具体见翼支付客户端权益专区展示内容。'),
#  Document(metadata={'source': '../data/问答题.txt', '_id': '9c7af493-4a77-40e7-8ebc-551e04485606', '_collection_name': '007'}, page_content='问：你们最近是有个存费送权益的活动吗\n答：您好，感谢您对安徽电信的关注，目前是有预存300元/600元，协议期6/12个月，分6/12个月返还话费，每个月返50元话费，并赠送对应的大权益包活动。')]

# %% [markdown]
# ### 第四步 检查文档相关性
# 使用MiniMaxChat语言模型进行判断相关性是否过滤掉不相关的文档块。

# %%
# Data model
class GradeDocuments(BaseModel):
    """对检索到的文档进行相关性检查"""

    binary_score: str = Field(
        description="Documents are relevant to the question, 'yes' or 'no'"
    )

llm = MiniMaxChat()
structured_llm_grader = llm.with_structured_output(GradeDocuments)

# Prompt
# 你是一个评分员，评估检索到的文档与用户问题的相关性。\ n
# 如果文档包含与用户问题相关的关键字或语义，则将其评为相关。\ n
# 它不需要是一个严格的测试。目标是过滤掉错误的检索。\ n
# 给出一个是否结果“是”或“否”，以表明该文档是否与问题相关。
system = """
    You are a grader assessing relevance of a retrieved document to a user question. \n 
    If the document contains keyword(s) or semantic meaning related to the user question, grade it as relevant. \n
    It does not need to be a stringent test. The goal is to filter out erroneous retrievals. \n
    Give a binary score 'yes' or 'no' score to indicate whether the document is relevant to the question.
"""

grade_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "Retrieved document: \n\n {document} \n\n User question: {question}"),
    ]
)

retrieval_grader = grade_prompt | structured_llm_grader

docs_to_use = []
for doc in context:
    print(doc.page_content, '\n', '-'*50)
    res = retrieval_grader.invoke({"question": question, "document": doc.page_content})
    print(res,'\n')
    if res.binary_score == 'yes':
        docs_to_use.append(doc)
# Out:
# 问：存费送权益活动期多久
# 答：您好，2024-08-01 00:00:00 开始到 2024-12-31 23:59:59 结束，如果您需要请及时参加。
#  --------------------------------------------------
# binary_score='yes'
#
# 问：存费送权益的活动内容是什么样的
# 答：活动1：预存300元，协议期6个月，分6个月返还话费，每个月返50元话费，并赠送大权益包A包。
# 活动2：预存600元，协议期12个月，分12个月返还话费，每个月返50元话费，并赠送大权益包B包。
#  --------------------------------------------------
# binary_score='yes'
#
# 问：存费送权益我能参加吗
# 答：您好，目前这个活动针对安徽电信翼支付预付费、后付费手机用户均可办理
#  --------------------------------------------------
# binary_score='yes'
#
# 问：存费送权益的的权益包是什么
# 答：大权益包A包：以下权益每月N选2：爱奇艺周卡/优酷周卡/腾讯周卡/5元水电煤缴费券/5元中石油加油券/5元商户券
# 大权益包B包：以下权益每月N选1：爱奇艺月卡/优酷月卡/腾讯月卡/15元水电煤缴费券（5元*3张）/15元中石油元券/15元商户券（5元*3张）
# 大权益包在总价值不减少的前提下，包含的内容可能会不定期进行更新调整，具体见翼支付客户端权益专区展示内容。
#  --------------------------------------------------
# binary_score='yes'
#
# 问：你们最近是有个存费送权益的活动吗
# 答：您好，感谢您对安徽电信的关注，目前是有预存300元/600元，协议期6/12个月，分6/12个月返还话费，每个月返50元话费，并赠送对应的大权益包活动。
#  --------------------------------------------------
# binary_score='yes'

# %% [markdown]
# ### 第五步 生成答案
# 使用相关文档块来生成对用户查询的简明答案。

# %%
# Prompt
# 你是负责回答问题的助手。根据你的知识回答问题。
# 最多用三到五个句子，回答要简明扼要
system = """
    You are an assistant for question-answering tasks. Answer the question based upon your knowledge. 
    Use three-to-five sentences maximum and keep the answer concise.
"""

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "Retrieved documents: \n\n <docs>{documents}</docs> \n\n User question: <question>{question}</question>"),
    ]
)

def format_docs(docs):
    return "\n".join(f"<doc{i+1}>:\nSource:{doc.metadata['source']}\nContent:{doc.page_content}\n</doc{i+1}>\n" for i, doc in enumerate(docs))

# Chain
rag_chain = prompt | llm | StrOutputParser()

# 生成答案
generation = rag_chain.invoke({"documents":format_docs(docs_to_use), "question": question})
print(generation)
# Out:
# 您好，存费送权益的活动有两种方案：活动1是预存300元，协议期6个月，分6个月返还话费，每个月返50元话费，并赠送大权益包A包；活动2是预存600元，协议期12个月，分12个月返还话费，每个月返50元话费，并赠送大权益包B包。

# %% [markdown]
# ### 第六步 幻觉检测
#
# 专用的幻觉检测步骤确保生成的答案基于检索到的文档，防止包含不支持或错误的信息。

# %%
# 对于幻觉检测，我们使用一个简单的是否评分系统，其中“是”表示答案基于检索到的文档，而“否”表示答案可能包含幻觉。
class GradeHallucinations(BaseModel):
    binary_score: str = Field(
        ...,
        description="Answer is grounded in the facts, 'yes' or 'no'"
    )


structured_llm_grader = llm.with_structured_output(GradeHallucinations)

# Prompt
system = """
    You are a grader assessing whether an LLM generation is grounded in / supported by a set of retrieved facts. \n 
    Give a binary score 'yes' or 'no'. 'Yes' means that the answer is grounded in / supported by the set of facts.
"""

hallucination_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "Set of facts: \n\n <facts>{documents}</facts> \n\n LLM generation: <generation>{generation}</generation>"),
    ]
)

hallucination_grader = hallucination_prompt | structured_llm_grader

response = hallucination_grader.invoke({"documents": format_docs(docs_to_use), "generation": generation})
print(response)
# Out:
# binary_score='yes'

# %% [markdown]
# ### 最后 显示答案使用的文档块
# 识别并突出显示检索到的文档中用于生成最终答案的确切片段块

# %%
from typing import List
from langchain.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate

# 返回文档中用于回答问题的特定部分
class HighlightDocuments(BaseModel):
    id: List[str] = Field(
        ...,
        description="List of id of docs used to answers the question"
    )

    source: List[str] = Field(
        ...,
        description="List of sources used to answers the question"
    )

    segment: List[str] = Field(
        ...,
        description="List of direct segements from used documents that answers the question"
    )

# parser
parser = PydanticOutputParser(pydantic_object=HighlightDocuments)

# Prompt
system = """
You are an advanced assistant for document search and retrieval. You are provided with the following:
1. A question.
2. A generated answer based on the question.
3. A set of documents that were referenced in generating the answer.

Your task is to identify and extract the exact inline segments from the provided documents that directly correspond to the content used to 
generate the given answer. The extracted segments must be verbatim snippets from the documents, ensuring a word-for-word match with the text 
in the provided documents.

Ensure that:
- (Important) Each segment is an exact match to a part of the document and is fully contained within the document text.
- The relevance of each segment to the generated answer is clear and directly supports the answer provided.
- (Important) If you didn't used the specific document don't mention it.

Used documents: <docs>{documents}</docs> \n\n User question: <question>{question}</question> \n\n Generated answer: <answer>{generation}</answer>

<format_instruction>
{format_instructions}
</format_instruction>
"""


prompt = PromptTemplate(
    template= system,
    input_variables=["documents", "question", "generation"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

# Chain
doc_lookup = prompt | llm | parser

# Run
lookup_response = doc_lookup.invoke({"documents":format_docs(docs_to_use), "question": question, "generation": generation})

# %%
for id, source, segment in zip(lookup_response.id, lookup_response.source, lookup_response.segment):
    print(f"ID: {id}\nSource: {source}\nText Segment: {segment}\n")
# Out:
# ID: doc2
# Source: ../data/问答题.txt
# Text Segment: 活动1：预存300元，协议期6个月，分6个月返还话费，每个月返50元话费，并赠送大权益包A包。
#
# ID: doc5
# Source: ../data/问答题.txt
# Text Segment: 活动2：预存600元，协议期12个月，分12个月返还话费，每个月返50元话费，并赠送大权益包B包。
